# %%
from ultralytics import YOLO
import cv2
import cvzone
import math
 
# cap = cv2.VideoCapture(0)  # For Webcam
# cap.set(3, 1280)
# cap.set(4, 720)
cap = cv2.VideoCapture('01.mp4')  # For Video
 
model = YOLO("best.pt")

# %%
classNames = ['Excavator', 'Gloves', 'Hardhat', 'Ladder', 'Mask', 'NO-Hardhat', 'NO-Mask', 'NO-Safety Vest', 'Person', 'SUV', 'Safety Cone', 'Safety Vest', 'bus', 'dump truck', 'fire hydrant', 'machinery', 'mini-van', 'sedan', 'semi', 'trailer', 'truck and trailer', 'truck', 'van', 'vehicle', 'wheel loader']

# %%
myColor = (0, 0, 255)
while True:
    success, img = cap.read()
    results = model(img, stream=True)
    for r in results:
        boxes = r.boxes
        for box in boxes:
            # Bounding Box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            # cv2.rectangle(img,(x1,y1),(x2,y2),(255,0,255),3)
            w, h = x2 - x1, y2 - y1
            # cvzone.cornerRect(img, (x1, y1, w, h))
 
            # Confidence
            conf = math.ceil((box.conf[0] * 100)) / 100
            # Class Name
            cls = int(box.cls[0])
            currentClass = classNames[cls]
            print(currentClass)
            if conf>0.5:
                if currentClass =='NO-Hardhat' or currentClass =='NO-Safety Vest' or currentClass == "NO-Mask":
                    myColor = (0, 0,255)
                elif currentClass =='Hardhat' or currentClass =='Safety Vest' or currentClass == "Mask":
                    myColor =(0,255,0)
                else:
                    myColor = (255, 0, 0)
 
                cvzone.putTextRect(img, f'{classNames[cls]} {conf}',
                                   (max(0, x1), max(35, y1)), scale=1, thickness=1,colorB=myColor,
                                   colorT=(255,255,255),colorR=myColor, offset=5)
                cv2.rectangle(img, (x1, y1), (x2, y2), myColor, 3)
 
    cv2.imshow("Image", img)
    cv2.waitKey(1)
    if cv2.waitKey(1) & 0xff == ord("q"):
        break
cv2.destroyAllWindows()
cap.release()
# Out:
# 0: 384x640 1 Gloves, 1 Hardhat, 1 NO-Mask, 1 NO-Safety Vest, 1 Person, 7425.4ms
# Person
# NO-Safety Vest
# Hardhat
# NO-Mask
# Gloves
# Speed: 1635.3ms preprocess, 7425.4ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gloves, 1 Hardhat, 1 NO-Mask, 1 NO-Safety Vest, 1 Person, 6628.4ms
# Person
# Hardhat
# NO-Safety Vest
# NO-Mask
# Gloves
# Speed: 94.1ms preprocess, 6628.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gloves, 1 Hardhat, 1 NO-Mask, 1 NO-Safety Vest, 1 Person, 7089.7ms
# Person
# NO-Safety Vest
# Hardhat
# NO-Mask
# Gloves
# Speed: 19.6ms preprocess, 7089.7ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gloves, 1 Hardhat, 1 NO-Mask, 1 NO-Safety Vest, 1 Person, 7150.8ms
# Person
# NO-Safety Vest
# Hardhat
# NO-Mask
# Gloves
# Speed: 65.9ms preprocess, 7150.8ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gloves, 1 Hardhat, 1 NO-Mask, 1 NO-Safety Vest, 1 Person, 6539.5ms
# Person
# NO-Safety Vest
# Hardhat
# NO-Mask
# Gloves
# Speed: 1509.5ms preprocess, 6539.5ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gloves, 1 Hardhat, 1 NO-Mask, 1 NO-Safety Vest, 1 Person, 7003.0ms
# Person
# NO-Safety Vest
# Hardhat
# NO-Mask
# Gloves
# Speed: 67.3ms preprocess, 7003.0ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Hardhat, 1 NO-Mask, 1 NO-Safety Vest, 1 Person, 6408.7ms
# Person
# Hardhat
# NO-Safety Vest
# NO-Mask
# Speed: 68.8ms preprocess, 6408.7ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)

# %%
from ultralytics import YOLO
import cv2
import cvzone
import math
 
# cap = cv2.VideoCapture(0)  # For Webcam
# cap.set(3, 1280)
# cap.set(4, 720)
cap = cv2.VideoCapture("../Videos/ppe-3.mp4")  # For Video
 
model = YOLO("best.pt")
 
classNames = ['Hardhat', 'Mask', 'NO-Hardhat', 'NO-Mask', 'NO-Safety Vest', 'Person', 'Safety Cone',
              'Safety Vest', 'machinery', 'vehicle']
myColor = (0, 0, 255)
while True:
    success, img = cap.read()
    results = model(img, stream=True)
    for r in results:
        boxes = r.boxes
        for box in boxes:
            # Bounding Box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            # cv2.rectangle(img,(x1,y1),(x2,y2),(255,0,255),3)
            w, h = x2 - x1, y2 - y1
            # cvzone.cornerRect(img, (x1, y1, w, h))
 
            # Confidence
            conf = math.ceil((box.conf[0] * 100)) / 100
            # Class Name
            cls = int(box.cls[0])
            currentClass = classNames[cls]
            print(currentClass)
            if conf>0.5:
                if currentClass =='NO-Hardhat' or currentClass =='NO-Safety Vest' or currentClass == "NO-Mask":
                    myColor = (0, 0,255)
                elif currentClass =='Hardhat' or currentClass =='Safety Vest' or currentClass == "Mask":
                    myColor =(0,255,0)
                else:
                    myColor = (255, 0, 0)
 
                cvzone.putTextRect(img, f'{classNames[cls]} {conf}',
                                   (max(0, x1), max(35, y1)), scale=1, thickness=1,colorB=myColor,
                                   colorT=(255,255,255),colorR=myColor, offset=5)
                cv2.rectangle(img, (x1, y1), (x2, y2), myColor, 3)
 
    cv2.imshow("Image", img)
    cv2.waitKey(1)
