# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Ijaz Ullah Khan\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8n.pt")

# %%
result = model("car03.webp",save = True)
# Out:
# image 1/1 c:\Users\Ijaz Ullah Khan\kpitb-ai-training\week07\car03.webp: 384x640 5 persons, 2 cars, 841.6ms
# Speed: 2078.4ms preprocess, 841.6ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to C:\Users\Ijaz Ullah Khan\kpitb-ai-training\week07\runs\detect\predict

# %%
print(result[0].boxes)

# %%
img_array = result[0].plot()
