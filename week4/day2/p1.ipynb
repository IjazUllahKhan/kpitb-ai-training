# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.13.0'

# %%
import numpy as np

# %%
img = cv2.imread("../cat01.jfif")

# %%
img.shape
# Out:
# (148, 270, 3)

# %%
img
# Out:
# array([[[ 19,  26,  13],
#         [ 19,  26,  13],
#         [ 19,  26,  13],
#         ...,
#         [ 10,  23,   9],
#         [ 10,  23,   9],
#         [ 10,  23,   9]],
#
#        [[ 19,  26,  13],
#         [ 19,  26,  13],
#         [ 19,  26,  13],
#         ...,
#         [ 10,  23,   9],
#         [ 10,  23,   9],
#         [ 10,  23,   9]],
#
#        [[ 19,  26,  13],
#         [ 19,  26,  13],
#         [ 19,  26,  13],
#         ...,
#         [ 10,  23,   9],
#         [ 10,  23,   9],
#         [ 11,  24,  10]],
#
#        ...,
#
#        [[ 37,  79,  54],
#         [ 35,  77,  52],
#         [ 37,  79,  56],
#         ...,
#         [ 34, 166, 166],
#         [ 40, 166, 167],
#         [ 44, 167, 169]],
#
#        [[ 37,  79,  54],
#         [ 35,  77,  52],
#         [ 37,  79,  56],
#         ...,
#         [ 41, 173, 173],
#         [ 37, 163, 164],
#         [ 34, 155, 157]],
#
#        [[ 37,  79,  54],
#         [ 35,  77,  52],
#         [ 37,  79,  56],
# ...

# %%
cv2.imshow("cat image",img)
cv2.waitKey(0)
# Out:
# -1

# %%
grayImg = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
grayImg.shape
# Out:
# (148, 270)

# %%
cv2.imshow("cat image",grayImg)
cv2.waitKey(0)
# Out:
# -1

# %%
img_rz = cv2.resize(img,(600,600))

# %%
img_rz.shape
# Out:
# (600, 600, 3)

# %%
cv2.imshow("cat image",img_rz)
cv2.waitKey(0)
# Out:
# -1
